# %% [markdown]
# # Hamlet unter der Lupe
#
# ## Projektidee
#
# * Hamlet einlesen
# * Extraktion, was Hamlet gesagt hat
# * Wie viele Worte verwendet Hamlet?
# * Wie viele eindeutige Worte verwendet Hamlet?
# * Wie viele eindeutige Worte verwendet Hamlet, die nicht Stopworte sind?
# * Histogramm der häufigsten Worte
# * Cloud-Tag der Worte
# * Künstlichen Zufallssatz anhand der Wortwahrscheinlichkeiten generieren
# * Bigrame und Trigrame erzeugen
# * Häufigkeiten der Bigrame und Trigrame erzeugen
# * Künstliche Sätze anhand der Häufigkeiten bilden

# %% [markdown]
# Einen Regulären Ausdruck der alle Blöcke findet, die von Hamlet gesprochen wurden und auf dem Originaltext beruht, habe ich bisher nicht gefunden. Passagen in denen Hamlet mehr als einen Satz sagt, habe ich derart zusammengefügt, dass sie nur aus einem zusammenhängenden String bestehen, der dann von jeweils zwei Leerzeichen begrenzt wird.
# P.S. bitte melden, falls das jemand mit nur einem einzigen Regulären Ausdruck hinbekommt.

# %%
# Hamlet einlesen
filename = open('hamlet.txt', encoding="utf-8")
text=filename.read()

# Problem zeigen

print (text[11500:13000])

# Wie sieht ein regulärer Ausdruck aus, der sowohl Einzelsätze von Hamlet 
# als auch Textblöcke extrahiert?
# Etwas in dieses Richtung funktioniert
# for match in re.findall(r'Ham\.\s*\n((?:.+\n)+)\n',hamlet_text):
#Bemerkung "(?:" ist eine Klammer die keine Gruppe bildet
#Ham. gefolgt von beliebig vielen Zeilen (aber mind 1) gefolgt von einem Zeilenumbruch
#Zeile ist ".*\n"
# Out:
#  best graces spend it at thy will!--
# But now, my cousin Hamlet, and my son--
#
# Ham.
# [Aside.] A little more than kin, and less than kind!
#
# King.
# How is it that the clouds still hang on you?
#
# Ham.
# Not so, my lord; I am too much i' the sun.
#
# Queen.
# Good Hamlet, cast thy nighted colour off,
# And let thine eye look like a friend on Denmark.
# Do not for ever with thy vailed lids
# Seek for thy noble father in the dust:
# Thou know'st 'tis common,--all that lives must die,
# Passing through nature to eternity.
#
# Ham.
# Ay, madam, it is common.
#
# Queen.
# If it be,
# Why seems it so particular with thee?
#
# Ham.
# Seems, madam! Nay, it is; I know not seems.
# 'Tis not alone my inky cloak, good mother,
# Nor customary suits of solemn black,
# Nor windy suspiration of forc'd breath,
# No, nor the fruitful river in the eye,
# Nor the dejected 'havior of the visage,
# Together with all forms, moods, shows of grief,
# That can denote me truly: these, indeed, seem;
# For they are actions that a man might play;
# But I have that within which passeth show;
# These but the trappings and the suits of woe.
#
# King.
# 'Tis sweet and commendable in your nature, Hamlet,
# To give these mourning duties to your father;
# But, you must know, your father lost a father;
# That father lost, lost his; and the survivor bound,
# In filial obligation, for some term
# To do obsequious sorrow: but to persevere
# In obstinate condolement is a course
# Of impious stubbornness; 'tis unmanly grief;
# It shows a will most incorrect to heaven;
# A heart unfortified, a mind imp

# %%
# alle Doppelzeilen eindeutig codieren
text = text.replace("\n\n", "###" )

# einfache Zeilen, die in einem Block sind aneinanderhängen
text = text.replace("\n", " ")

# Die doppelten Leerzeilen wieder herstellen
text = text.replace("###", "\n\n")

print (text[11500:13000])
# Out:
#  best graces spend it at thy will!-- But now, my cousin Hamlet, and my son--
#
# Ham. [Aside.] A little more than kin, and less than kind!
#
# King. How is it that the clouds still hang on you?
#
# Ham. Not so, my lord; I am too much i' the sun.
#
# Queen. Good Hamlet, cast thy nighted colour off, And let thine eye look like a friend on Denmark. Do not for ever with thy vailed lids Seek for thy noble father in the dust: Thou know'st 'tis common,--all that lives must die, Passing through nature to eternity.
#
# Ham. Ay, madam, it is common.
#
# Queen. If it be, Why seems it so particular with thee?
#
# Ham. Seems, madam! Nay, it is; I know not seems. 'Tis not alone my inky cloak, good mother, Nor customary suits of solemn black, Nor windy suspiration of forc'd breath, No, nor the fruitful river in the eye, Nor the dejected 'havior of the visage, Together with all forms, moods, shows of grief, That can denote me truly: these, indeed, seem; For they are actions that a man might play; But I have that within which passeth show; These but the trappings and the suits of woe.
#
# King. 'Tis sweet and commendable in your nature, Hamlet, To give these mourning duties to your father; But, you must know, your father lost a father; That father lost, lost his; and the survivor bound, In filial obligation, for some term To do obsequious sorrow: but to persevere In obstinate condolement is a course Of impious stubbornness; 'tis unmanly grief; It shows a will most incorrect to heaven; A heart unfortified, a mind imp

# %%
import re
regex = re.compile('Ham\. (.+)\n\n')
hamlet= regex.findall(text)

print(hamlet[:100])
# Out:
# ['[Aside.] A little more than kin, and less than kind!', "Not so, my lord; I am too much i' the sun.", 'Ay, madam, it is common.', "Seems, madam! Nay, it is; I know not seems. 'Tis not alone my inky cloak, good mother, Nor customary suits of solemn black, Nor windy suspiration of forc'd breath, No, nor the fruitful river in the eye, Nor the dejected 'havior of the visage, Together with all forms, moods, shows of grief, That can denote me truly: these, indeed, seem; For they are actions that a man might play; But I have that within which passeth show; These but the trappings and the suits of woe.", 'I shall in all my best obey you, madam.', "O that this too too solid flesh would melt, Thaw, and resolve itself into a dew! Or that the Everlasting had not fix'd His canon 'gainst self-slaughter! O God! O God! How weary, stale, flat, and unprofitable Seem to me all the uses of this world! Fie on't! O fie! 'tis an unweeded garden, That grows to seed; things rank and gross in nature Possess it merely. That it should come to this! But two months dead!--nay, not so much, not two: So excellent a king; that was, to this, Hyperion to a satyr; so loving to my mother, That he might not beteem the winds of heaven Visit her face too roughly. Heaven and earth! Must I remember? Why, she would hang on him As if increase of appetite had grown By what it fed on: and yet, within a month,-- Let me not think on't,--Frailty, thy name is woman!-- A little month; or ere those shoes were old With which she followed my poor father's body Like Niobe, all tears;--why she, even she,-- O God! a beast that wants discourse of reason, Would have mourn'd longer,--married with mine uncle, My father's brother; but no more like my father Than I to Hercules: within a month; Ere yet the salt of most unrighteous tears Had left the flushing in her galled eyes, She married:-- O, most wicked speed, to post With such dexterity to incestuous sheets! It is not, nor it cannot come to good; But break my heart,--for I must hold my tongue!", 'I am glad to see you well: Horatio,--or I do forget myself.', "Sir, my good friend; I'll change that name with you: And what make you from Wittenberg, Horatio?-- Marcellus?", 'I am very glad to see you.--Good even, sir.-- But what, in faith, make you from Wittenberg?', "I would not hear your enemy say so; Nor shall you do my ear that violence, To make it truster of your own report Against yourself: I know you are no truant. But what is your affair in Elsinore? We'll teach you to drink deep ere you depart.", "I prithee do not mock me, fellow-student. I think it was to see my mother's wedding.", "Thrift, thrift, Horatio! The funeral bak'd meats Did coldly furnish forth the marriage tables. Would I had met my dearest foe in heaven Or ever I had seen that day, Horatio!-- My father,--methinks I see my father.", "In my mind's eye, Horatio.", 'He was a man, take him for all in all, I shall not look upon his like again.', 'Saw who?', 'The King my father!', "For God's love let me hear.", 'But where was this?', 'Did you not speak to it?', "'Tis very strange.", 'Indeed, indeed, sirs, but this troubles me. Hold you the watch to-night?', "Arm'd, say you?", 'From top to toe?', 'Then saw you not his face?', "What, look'd he frowningly?", 'Pale or red?', "And fix'd his eyes upon you?", 'I would I had been there.', "Very like, very like. Stay'd it long?", 'His beard was grizzled,--no?', "I will watch to-night; Perchance 'twill walk again.", "If it assume my noble father's person, I'll speak to it, though hell itself should gape And bid me hold my peace. I pray you all, If you have hitherto conceal'd this sight, Let it be tenable in your silence still; And whatsoever else shall hap to-night, Give it an understanding, but no tongue: I will requite your loves. So, fare ye well: Upon the platform, 'twixt eleven and twelve, I'll visit you.", 'Your loves, as mine to you: farewell.', 'The air bites shrewdly; it is very cold.', 'What hour now?', 'The King doth wake  ...

# %%
# einen großen String raus machen
hamlet = " ".join(hamlet)
print (hamlet[:500])
# Out:
# [Aside.] A little more than kin, and less than kind! Not so, my lord; I am too much i' the sun. Ay, madam, it is common. Seems, madam! Nay, it is; I know not seems. 'Tis not alone my inky cloak, good mother, Nor customary suits of solemn black, Nor windy suspiration of forc'd breath, No, nor the fruitful river in the eye, Nor the dejected 'havior of the visage, Together with all forms, moods, shows of grief, That can denote me truly: these, indeed, seem; For they are actions that a man might pla

# %%
# Bereinigungen

# Alles weg, was zwischen [] steht
regex = re.compile('(\[.+?\])')
hamlet= regex.sub("",hamlet)

# Alle Satzzeichen entfernen
regex = re.compile('[\.!\?.:,;]')
hamlet = regex.sub("",hamlet)

# Alle -- entfernen
regex = re.compile('--')
hamlet = regex.sub(" ",hamlet)

print(hamlet[:1000])
# Out:
#  A little more than kin and less than kind Not so my lord I am too much i' the sun Ay madam it is common Seems madam Nay it is I know not seems 'Tis not alone my inky cloak good mother Nor customary suits of solemn black Nor windy suspiration of forc'd breath No nor the fruitful river in the eye Nor the dejected 'havior of the visage Together with all forms moods shows of grief That can denote me truly these indeed seem For they are actions that a man might play But I have that within which passeth show These but the trappings and the suits of woe I shall in all my best obey you madam O that this too too solid flesh would melt Thaw and resolve itself into a dew Or that the Everlasting had not fix'd His canon 'gainst self-slaughter O God O God How weary stale flat and unprofitable Seem to me all the uses of this world Fie on't O fie 'tis an unweeded garden That grows to seed things rank and gross in nature Possess it merely That it should come to this But two months dead nay not so much

# %%
# Tokens durch split() erstellen
# NLP-Tokenizer aus der NLTK- oder spaCy.io-Bibliothek können das noch besser
hamlettokens=hamlet.split()
print (hamlettokens[:100])
# Out:
# ['A', 'little', 'more', 'than', 'kin', 'and', 'less', 'than', 'kind', 'Not', 'so', 'my', 'lord', 'I', 'am', 'too', 'much', "i'", 'the', 'sun', 'Ay', 'madam', 'it', 'is', 'common', 'Seems', 'madam', 'Nay', 'it', 'is', 'I', 'know', 'not', 'seems', "'Tis", 'not', 'alone', 'my', 'inky', 'cloak', 'good', 'mother', 'Nor', 'customary', 'suits', 'of', 'solemn', 'black', 'Nor', 'windy', 'suspiration', 'of', "forc'd", 'breath', 'No', 'nor', 'the', 'fruitful', 'river', 'in', 'the', 'eye', 'Nor', 'the', 'dejected', "'havior", 'of', 'the', 'visage', 'Together', 'with', 'all', 'forms', 'moods', 'shows', 'of', 'grief', 'That', 'can', 'denote', 'me', 'truly', 'these', 'indeed', 'seem', 'For', 'they', 'are', 'actions', 'that', 'a', 'man', 'might', 'play', 'But', 'I', 'have', 'that', 'within', 'which']

# %%
# Tokens normieren in Kleinbuchstaben
# Verwendung von List-Comprehension
hamletltokens=[word.lower() for word in hamlettokens]
hamletltokens[:10]

# Kurzversion von:
# hamletltokens=[]
# for word in hamlettokens:
#    word = word.lower()
#    hamlettokens.append(word)
# Out:
# ['a', 'little', 'more', 'than', 'kin', 'and', 'less', 'than', 'kind', 'not']

# %%
# Wie viele Worte spendiert Shakespeare für Hamlet
print (len(hamletltokens))
# Out:
# 10706

# %%
# Wie viele unterschiedliche Worte spendiert Shakespeare für Hamlet
uniqueltokens=set(hamletltokens)
print (len(uniqueltokens))
# Out:
# 2517

# %%
# Basisstatistiken zur Wortlänge
import statistics
wortlaengen = [len(word) for word in hamletltokens]
print ("Mittelwert:", statistics.mean(wortlaengen))
print ("Modalwert: ", statistics.mode(wortlaengen))
print ("Median:    ", statistics.median(wortlaengen))
print ("Minimum:   ", min(wortlaengen))
print ("Maximum:   ", max(wortlaengen))
print ("Stdev:     ", statistics.stdev(wortlaengen))
# Out:
# Mittelwert: 4.077620026153559
# Modalwert:  4
# Median:     4.0
# Minimum:    1
# Maximum:    16
# Stdev:      2.086465756139522

# %%
# Wie viele unterschiedliche Worte bleiben übrig, wenn man die Stoppworte eleminiert
stopwords = set(["a", "about", "above", "above", "across", "after", "afterwards", "again", "against", "all", "almost", "alone", "along", "already", "also","although","always","am","among", "amongst", "amoungst", "amount",  "an", "and", "another", "any","anyhow","anyone","anything","anyway", "anywhere", "are", "around", "as",  "at", "back","be","became", "because","become","becomes", "becoming", "been", "before", "beforehand", "behind", "being", "below", "beside", "besides", "between", "beyond", "bill", "both", "bottom","but", "by", "call", "can", "cannot", "cant", "co", "con", "could", "couldnt", "cry", "de", "describe", "detail", "do", "done", "down", "due", "during", "each", "eg", "eight", "either", "eleven","else", "elsewhere", "empty", "enough", "etc", "even", "ever", "every", "everyone", "everything", "everywhere", "except", "few", "fifteen", "fify", "fill", "find", "fire", "first", "five", "for", "former", "formerly", "forty", "found", "four", "from", "front", "full", "further", "get", "give", "go", "had", "has", "hasnt", "have", "he", "hence", "her", "here", "hereafter", "hereby", "herein", "hereupon", "hers", "herself", "him", "himself", "his", "how", "however", "hundred", "ie", "if", "in", "inc", "indeed", "interest", "into", "is", "it", "its", "itself", "keep", "last", "latter", "latterly", "least", "less", "ltd", "made", "many", "may", "me", "meanwhile", "might", "mill", "mine", "more", "moreover", "most", "mostly", "move", "much", "must", "my", "myself", "name", "namely", "neither", "never", "nevertheless", "next", "nine", "no", "nobody", "none", "noone", "nor", "not", "nothing", "now", "nowhere", "of", "off", "often", "on", "once", "one", "only", "onto", "or", "other", "others", "otherwise", "our", "ours", "ourselves", "out", "over", "own","part", "per", "perhaps", "please", "put", "rather", "re", "same", "see", "seem", "seemed", "seeming", "seems", "serious", "several", "she", "should", "show", "side", "since", "sincere", "six", "sixty", "so", "some", "somehow", "someone", "something", "sometime", "sometimes", "somewhere", "still", "such", "system", "take", "ten", "than", "that", "the", "their", "them", "themselves", "then", "thence", "there", "thereafter", "thereby", "therefore", "therein", "thereupon", "these", "they", "thickv", "thin", "third", "this", "those", "though", "three", "through", "throughout", "thru", "thus", "to", "together", "too", "top", "toward", "towards", "twelve", "twenty", "two", "un", "under", "until", "up", "upon", "us", "very", "via", "was", "we", "well", "were", "what", "whatever", "when", "whence", "whenever", "where", "whereafter", "whereas", "whereby", "wherein", "whereupon", "wherever", "whether", "which", "while", "whither", "who", "whoever", "whole", "whom", "whose", "why", "will", "with", "within", "without", "would", "yet", "you", "your", "yours", "yourself", "yourselves", "the"])
# leider nur modernes Englisch
# Mengendifferenz bilden (sowohl uniqueltokens als auch stopwords sind Mengen)
uniqueltokens_nostop = uniqueltokens - stopwords
print (len(uniqueltokens_nostop))
# Out:
# 2306

# %%
# Wie oft kommen diese unterschiedlichen Worte vor
# verwende ein Dictionary, um die Worte auszuzählen

tokendict_nostop = {ut : hamletltokens.count(ut) for ut in uniqueltokens_nostop}
tokendict = {ut : hamletltokens.count(ut) for ut in uniqueltokens}


# Kurzversion von:
# tokendict={}
# for ut in uniquelctokens:
#    tokendict[ut]=hamletltokens.count(ut)

# %%
from collections import Counter
# Mit einem Counter geht das sogar noch ein wenig einfacher
# Er liefert ein Dictionary direkter und hat die Methode most_common(n) mit der 
# die n häufigsten Worte ermittelt werden können

tokencounter_nostop = Counter(hamlettokens) 
tokencounter_nostop
# Out:
# Counter({'minister': 1,
#          'lest': 2,
#          'foh': 1,
#          'mobled': 1,
#          'horridly': 1,
#          'under': 1,
#          'Hercules': 2,
#          'providence': 1,
#          're-word': 1,
#          'body': 6,
#          'paradox': 1,
#          'Dost': 4,
#          'action': 6,
#          'sorry': 2,
#          'learning': 1,
#          'things': 3,
#          'dismantled': 1,
#          'fancy': 1,
#          "find'st": 1,
#          'Like': 3,
#          'pat': 1,
#          'hadst': 1,
#          'pronounced': 1,
#          'Queen': 2,
#          'variable': 1,
#          'Rebellious': 1,
#          'often': 1,
#          'lose': 1,
#          'Remember': 2,
#          'Lady': 2,
#          'justly': 1,
#          'extent': 1,
#          'seeming': 1,
#          "punish'd": 1,
#          'grave-making': 1,
#          'memory': 5,
#          'wants': 1,
#          'One': 5,
#          'special': 2,
#          'poison': 2,
#          'effects': 1,
#          "season'd": 1,
#          'strumpet': 1,
#          'opposites': 1,
#          "pardon't": 1,
#          'ignorance': 3,
#          'wake': 1,
#          'breach': 1,
#          'Such': 3,
#          'Free': 1,
#          'Touching': 1,
#          'verse': 1,
#          'no': 41,
#          'hobby-horse': 2,
#          'Soil': 1,
#          'well': 26,
#          'majestical': 1,
#          'ills': 1,
#          'attribute': 1,
#          'Hide': 1,
#          'petty': 1,
#          'maintains': 1,
#          'fly': 2,
#          'Upon': 5,
#          'praised': 1,
#          'holds': 1,
#          'nowhere': 1,
#          'looked': 1,
#          'scandal': 1,
#          "speak'": 1,
#          'blown': 1,
#          'Hold': 3,
#          "know'st": 1,
#          'revengeful': 1,
#          'article': 1,
#          'reputation': 1,
#          'offended': 1,
#          'John-a-dreams': 1,
#          'makes': 8,
#          'remains': 1,
#          'wrinkled': 1,
#          'standing': 1,
#          'As': 23,
#          "o'ergrowth": 1,
#          'peasant': 2,
#          'chiefly': 1,
#          'poor': 10,
#          'double': 2,
#          'strangely': 1,
#          'happy': 1,
#          'desert': 1,
#          'heart': 11,
#          'England': 7,
#          'Must': 3,
#          'prevent': 1,
#          'slave': 4,
#          'innocent': 1,
#          'why': 12,
#          'unction': 1,
#          'Let': 14,
#          'An': 2,
#          'nations': 1,
#          'Roscius': 1,
#          'eleven': 1,
#          "mother's": 2,
#          'try': 1,
#          'having': 1,
#          'weary': 2,
#          'take': 12,
#          'profit': 1,
#          'By-and-by': 1,
#          'buzz': 1,
#          'understand': 1,
#          'Niobe': 1,
#          'trappings': 1,
#          'comes': 7,
#          'hawk': 1,
#          'changeling': 1,
#          'incensed': 1,
#          'broken': 1,
#          'perfect': 1,
#          'beaten': 1,
#          'eat': 5,
#          'Hyperion': 1,
#          'custom': 4,
#          'concernings': 1,
#          "Woul't": 2,
#          "soe'er": 1,
#          'Hillo': 1,
#          'fight': 2,
#          'prophesy': 2,
#          'came': 3,
#          'Dead': 1,
#          'reigns': 1,
#          'times': 4,
#          "we'll": 2,
#          'list': 1,
#          'whereto': 3,
#          'recorders': 1,
#          'cold': 2,
#          'working': 1,
#          'Makes': 1,
#          'forgotten': 1,
#          'split': 1,
#          'abhorred': 1,
#          'abstinence': 1,
#          'ducats': 2,
#          'exact': 1,
#          'bounded': 1,
#          'Wherein': 2,
#          'false': 2,
#          'tremble': 1,
#          'actions': 2,
#          'stiffly': 1,
#          'air': 4,
#          'yard': 1,
#          'groundas': 1,
#          'ways': 2,
#          "grave's": 1,
#          'son': 5,
#          'winnowed': 1,
#          'wag': 1,
#          'wondrous': 1,
#          'rogue': 1,
#          'forget': 2,
#          "damn'd": 5,
#          'pulse': 1,
#          'portraiture': 1,
#          'spacious': 1,
#          'hearsed': 1,
#          'bawdry': 1,
#          'dozen': 1,
#          "mind's": 1,
#          'twelve': 1,
#          'favours': 2,
#          'neither': 4,
#          'gait': 1,
#          'neck': 2,
#          'on': 34,
#          'sore': 1,
#          'rule': 1,
#          'hopes': 1,
#          "braz'd": 1,
#          'merry': 1,
#          'Laertes': 6,
#          'borne': 2,
#          'worst': 1,
#          'Sense': 1,
#          "if't": 1,
#          'demanded': 1,
#          "thinks't": 1,
#          'profanely': 1,
#          'choler': 1,
#          'reechy': 1,
#          'accent': 1,
#          'for': 74,
#          'melt': 2,
#          'clay': 1,
#          'escoted': 1,
#          'mouse': 1,
#          'whips': 1,
#          "That's": 2,
#          'german': 1,
#          'nerve': 1,
#          'odds': 2,
#          'Something': 1,
#          'diligence': 1,
#          'gently': 1,
#          'cue': 1,
#          'Even': 1,
#          'judgment': 3,
#          'cherub': 1,
#          'request': 1,
#          'possible': 1,
#          'dumb': 1,
#          'enterprises': 1,
#          'heavy': 1,
#          'lines': 3,
#          'thereabout': 1,
#          'accuse': 1,
#          'yourselves': 1,
#          'Look': 6,
#          "conceal'd": 1,
#          'use': 7,
#          "Here's": 1,
#          'knock': 1,
#          'baseness': 1,
#          'Forgive': 1,
#          'wicked': 3,
#          'skill': 1,
#          'dwelling': 1,
#          'angel': 2,
#          'You': 14,
#          'place': 3,
#          'compare': 1,
#          'Safely': 1,
#          'gibes': 1,
#          'kettle-drum': 1,
#          'clepe': 1,
#          'pale': 3,
#          'oft': 2,
#          'courtier': 2,
#          "'The": 2,
#          'counsellor': 1,
#          'might': 14,
#          'hour': 1,
#          'ye': 3,
#          'lie': 6,
#          'front': 1,
#          'meats': 1,
#          'speed': 1,
#          'fellow': 8,
#          "milldew'd": 1,
#          "heart's": 1,
#          'triumph': 1,
#          'touches': 1,
#          'past': 2,
#          'serves': 1,
#          'carriages': 2,
#          'packing': 1,
#          'fretted': 1,
#          'generous': 1,
#          'Wretched': 1,
#          "nature's": 2,
#          'dignity': 1,
#          'odd': 2,
#          'saw': 3,
#          "kill'd": 1,
#          'flushing': 1,
#          'box': 1,
#          'mandate': 1,
#          'equivocation': 1,
#          'test': 1,
#          'years': 1,
#          'The': 39,
#          'dies': 1,
#          'musty': 1,
#          'violence': 2,
#          'fawning': 1,
#          'burn': 1,
#          'groundlings': 1,
#          'Methinks': 2,
#          "queen'": 1,
#          "laps'd": 1,
#          'grunt': 1,
#          'sickly': 2,
#          'beget': 1,
#          'wrong': 4,
#          'little': 6,
#          'fare': 1,
#          'grey': 1,
#          'escape': 1,
#          'quickly': 1,
#          'commandment': 1,
#          'suiting': 1,
#          "'twixt": 1,
#          'flashes': 1,
#          'aptly': 1,
#          'dreamt': 1,
#          'remove': 1,
#          'quick': 4,
#          'mad': 5,
#          'dangerous': 2,
#          'wormwood': 1,
#          'presentment': 1,
#          'Infects': 1,
#          'picked': 2,
#          'rareness': 1,
#          'gape': 1,
#          'went': 1,
#          'bound': 1,
#          'His': 6,
#          "you'll": 3,
#          'Jove': 2,
#          'friend': 2,
#          'sepulchre': 1,
#          'method': 1,
#          'bites': 1,
#          'enact': 1,
#          'fish': 2,
#          'university': 1,
#          'pestilent': 1,
#          'night': 5,
#          'truant': 1,
#          'Been': 1,
#          'do': 43,
#          'suffer': 3,
#          'played': 1,
#          'poisoning': 1,
#          'scene': 2,
#          "mourn'd": 1,
#          'youth': 4,
#          'outface': 1,
#          'calls': 2,
#          'glow': 1,
#          'breaking': 1,
#          'soldiers': 1,
#          'gives': 4,
#          'Consent': 1,
#          'swear': 1,
#          'go': 17,
#          'need': 2,
#          'toward': 1,
#          'Mercury': 1,
#          "conjoin'd": 1,
#          'chamber': 1,
#          'round': 1,
#          "whor'd": 1,
#          'sweet': 4,
#          'piece': 2,
#          'Give': 7,
#          'honeying': 1,
#          'These': 3,
#          'groaning': 1,
#          'office': 1,
#          'ice': 1,
#          'sort': 1,
#          'exercises': 1,
#          'trust': 1,
#          'clown': 1,
#          'draughts': 1,
#          'hold': 10,
#          'assume': 2,
#          'trivial': 1,
#          "wish'd": 1,
#          'fellowship': 2,
#          'main': 1,
#          'instrument': 1,
#          'sight': 2,
#          'penetrable': 1,
#          'change': 2,
#          'Murder': 1,
#          'grace': 7,
#          "We'll": 2,
#          'sitting': 1,
#          'Am': 2,
#          'seek': 3,
#          'towering': 1,
#          'what': 45,
#          'flat': 1,
#          'feathers': 1,
#          'inoculate': 1,
#          'delve': 1,
#          'revolution': 1,
#          'treacherous': 1,
#          'bonnet': 1,
#          'admit': 1,
#          'prologue': 2,
#          'distracted': 1,
#          'possession': 1,
#          'mirror': 2,
#          'virtue': 6,
#          'acres': 1,
#          'appurtenance': 1,
#          'fear': 2,
#          "well'": 1,
#          'pain': 1,
#          'whensoever': 1,
#          'therefore': 3,
#          'indiscretion': 1,
#          'Soft': 1,
#          'airs': 1,
#          'bourn': 1,
#          'unpack': 1,
#          'backward': 1,
#          "woul't": 3,
#          'Larded': 1,
#          'lot': 1,
#          'commingled': 1,
#          "allow'd": 1,
#          'ducat': 1,
#          'chances': 2,
#          'hitherto': 1,
#          'forms': 3,
#          'even': 6,
#          'gorge': 1,
#          'kick': 1,
#          "murder'd": 1,
#          'vapours': 1,
#          "lov'd": 2,
#          'make': 31,
#          'said': 4,
#          'keeps': 1,
#          'hypocrite': 1,
#          'beast': 2,
#          'morrow': 1,
#          'canst': 2,
#          "lion's": 1,
#          'salary': 1,
#          'rusty': 1,
#          'pocket': 1,
#          'politic': 1,
#          'tears': 4,
#          'King': 3,
#          "ta'en": 2,
#          'lands': 1,
#          'did': 15,
#          'swearing': 1,
#          "plac'd": 1,
#          'dig': 1,
#          'pause': 1,
#          'old': 8,
#          'volume': 1,
#          'neighbour': 1,
#          'hell': 6,
#          'herald': 1,
#          'twentieth': 1,
#          'sheets': 1,
#          'basket': 2,
#          'spurns': 1,
#          'with': 69,
#          'she': 10,
#          'once': 7,
#          'across': 1,
#          'sultry': 1,
#          'Is': 11,
#          'eye': 4,
#          'beteem': 1,
#          'stale': 1,
#          'ring': 1,
#          'leaves': 1,
#          'dish': 1,
#          'those': 8,
#          'months': 2,
#          'colour': 2,
#          'affair': 1,
#          'thanks': 3,
#          'allowance': 1,
#          "Gonzago's": 1,
#          "Stew'd": 1,
#          'faction': 1,
#          'best': 3,
#          "in't": 6,
#          'whipped': 1,
#          'earth': 11,
#          'golden': 1,
#          'imaginations': 1,
#          'Beggar': 1,
#          'live': 9,
#          'compound': 1,
#          "man's": 3,
#          'Excellent': 2,
#          'intruding': 1,
#          'woe': 1,
#          'Tears': 1,
#          'periwig-pated': 1,
#          'confession': 1,
#          'lips': 2,
#          'denote': 1,
#          'fiction': 1,
#          'reasons': 1,
#          'length': 2,
#          'likes': 2,
#          'Lay': 1,
#          'nose': 2,
#          'blush': 2,
#          'asleep': 1,
#          'peating': 1,
#          'Put': 1,
#          'mighty': 1,
#          'robustious': 1,
#          'house': 2,
#          'hath': 12,
#          'jig-maker': 1,
#          'instructs': 1,
#          'rage': 1,
#          'comment': 1,
#          'wounded': 1,
#          'fell': 2,
#          'doctor': 1,
#          'When': 8,
#          'Thou': 7,
#          'southerly': 1,
#          'revel': 1,
#          'amaze': 1,
#          'abominably': 1,
#          "'As": 1,
#          'Were': 1,
#          'sixteen': 1,
#          'native': 2,
#          'pursy': 1,
#          'revenge': 3,
#          'other': 6,
#          'plague': 1,
#          'mother': 23,
#          'below': 1,
#          'dost': 6,
#          'bed': 4,
#          "what's": 2,
#          'cabin': 1,
#          'I': 223,
#          'commission': 3,
#          'fashion': 2,
#          'wear': 3,
#          'offences': 1,
#          'tardy': 2,
#          'vicious': 1,
#          'occurrents': 1,
#          'horses': 1,
#          'vision': 1,
#          'slings': 1,
#          'certain': 1,
#          'purse': 1,
#          'fond': 1,
#          'eisel': 1,
#          'To': 32,
#          'faculties': 2,
#          'Was': 1,
#          'cunning': 2,
#          'precedent': 1,
#          'ends': 1,
#          'How': 22,
#          'tricks': 1,
#          "gave't": 1,
#          'effect': 2,
#          'Ossa': 1,
#          'Abuses': 1,
#          'Without': 1,
#          'win': 2,
#          'property': 1,
#          'honest': 8,
#          'sea': 1,
#          'Pah': 1,
#          'trace': 2,
#          'blows': 1,
#          'speak': 17,
#          'leisure': 2,
#          'plays': 1,
#          'mock': 3,
#          'denies': 1,
#          'union': 1,
#          'croaking': 1,
#          'couple': 1,
#          'thick': 2,
#          'Once': 2,
#          'perceive': 1,
#          'jowls': 1,
#          'outlive': 1,
#          'birds': 1,
#          'dull': 1,
#          'contumely': 1,
#          'wonder-wounded': 1,
#          'rivet': 1,
#          'forty': 2,
#          'friends': 7,
#          'tristful': 1,
#          'capital': 1,
#          'grown': 2,
#          'dry': 1,
#          'alone': 3,
#          'By': 3,
#          "Cain's": 1,
#          'puzzles': 1,
#          'jaws': 1,
#          'relative': 1,
#          'hole': 1,
#          'melancholy': 1,
#          'observance': 2,
#          'fighting': 1,
#          'quillets': 1,
#          'unskilful': 1,
#          'prophetic': 1,
#          'wipe': 1,
#          'region': 1,
#          'empire': 1,
#          'Whom': 1,
#          "liv'd": 1,
#          'recovery': 1,
#          'wiseness': 1,
#          "grows'": 1,
#          "envenom'd": 1,
#          'glass': 1,
#          'ever-preserved': 1,
#          'shelf': 1,
#          'With': 15,
#          'bout': 1,
#          'acquire': 1,
#          "'havior": 1,
#          'fair': 12,
#          'dread': 2,
#          'wassail': 1,
#          'Gonzago': 2,
#          'trumpet': 1,
#          'salvation': 1,
#          'realm': 1,
#          'within': 6,
#          'wherein': 1,
#          'fault': 1,
#          'yesty': 1,
#          'ordinant': 1,
#          'liest': 2,
#          'This': 14,
#          'new': 1,
#          'northerly': 1,
#          'lighted': 1,
#          'necessary': 1,
#          'pious': 1,
#          'Termagant': 1,
#          "believ'd": 1,
#          'save': 1,
#          'solid': 1,
#          'complexion': 2,
#          'baser': 2,
#          "despis'd": 1,
#          'writ': 1,
#          'doomsday': 1,
#          'methought': 1,
#          'foil': 2,
#          'west': 1,
#          'busy': 1,
#          'defy': 1,
#          'election': 3,
#          'foul': 2,
#          'whole': 4,
#          'every': 3,
#          'any': 2,
#          'unworthy': 2,
#          'lap': 2,
#          'drown': 1,
#          'theme': 1,
#          'skin': 1,
#          "passion's": 1,
#          'fool': 5,
#          'plunge': 1,
#          'short': 1,
#          'hand': 4,
#          'an': 24,
#          'sergeant': 1,
#          'arrest': 1,
#          'born': 2,
#          'cast': 2,
#          'hire': 1,
#          'snow': 1,
#          'her': 22,
#          'aunt-mother': 1,
#          'like': 26,
#          'adieu': 1,
#          'up': 9,
#          'For': 22,
#          'flourish': 2,
#          'lief': 1,
#          'deed': 2,
#          'nutshell': 1,
#          'sweep': 2,
#          'dearest': 1,
#          'face': 6,
#          'proper': 1,
#          'power': 2,
#          'wife': 5,
#          'Or': 15,
#          'each': 3,
#          'insolence': 1,
#          'back': 1,
#          'marshal': 1,
#          'bear': 7,
#          "pleas'd": 1,
#          'gambols': 1,
#          'bodkin': 1,
#          "he'll": 1,
#          'tempt': 1,
#          'film': 1,
#          'Two': 1,
#          'rot': 1,
#          'And': 68,
#          'Yet': 2,
#          'nomination': 1,
#          'knew': 1,
#          'beer-barrel': 1,
#          'anticipation': 1,
#          'counsel': 2,
#          "o'er-leavens": 1,
#          'post': 1,
#          'Herod': 1,
#          'thousand': 7,
#          'seem': 4,
#          'into': 8,
#          'before': 4,
#          'pleasing': 1,
#          'dreams': 2,
#          'deserve': 1,
#          'sables': 1,
#          'look': 11,
#          'pleased': 1,
#          'mark': 2,
#          'Between': 2,
#          'hard': 1,
#          'without': 5,
#          'burning': 1,
#          'lungs': 2,
#          'presence': 1,
#          "'For": 1,
#          'Rest': 1,
#          'religion': 1,
#          'villanies': 1,
#          'judicious': 1,
#          'paragon': 1,
#          'written': 1,
#          'poisons': 1,
#          "'tween": 1,
#          'boys': 1,
#          'lights': 1,
#          'shovel': 1,
#          "prais'd": 1,
#          'drink': 4,
#          'quantity': 3,
#          'foils': 3,
#          'belike': 1,
#          'replication': 1,
#          'customary': 1,
#          'easier': 1,
#          'soft': 2,
#          'unseen': 1,
#          "King's": 1,
#          "Vulcan's": 1,
#          "revenge'": 1,
#          'fishmonger': 1,
#          'crab': 1,
#          'Drink': 1,
#          'burst': 2,
#          'several': 1,
#          'angle': 1,
#          'dirty': 1,
#          'fanned': 1,
#          'fall': 2,
#          'fie': 2,
#          'satirical': 1,
#          'smile': 2,
#          'garden': 2,
#          "o'er-crows": 1,
#          "'If": 1,
#          'heartily': 2,
#          'line': 2,
#          'quintessence': 1,
#          'pure': 2,
#          "proclaim'd": 1,
#          "look'd": 1,
#          'Devoutly': 1,
#          'frame': 1,
#          'bounty': 1,
#          'excellent': 6,
#          'rhapsody': 1,
#          'death': 8,
#          'requite': 1,
#          "lady's": 1,
#          'indifferent': 1,
#          'divinity': 1,
#          'Ears': 1,
#          'immortal': 1,
#          'dearth': 1,
#          'watch': 3,
#          'hours': 1,
#          'cursed': 1,
#          'Yea': 3,
#          'drunkards': 1,
#          'command': 4,
#          'addition': 1,
#          'harsh': 1,
#          'knight': 1,
#          'wedding': 1,
#          'enginer': 1,
#          'What': 24,
#          'supper': 1,
#          "wot'": 1,
#          'capable': 2,
#          'enseamed': 1,
#          'Well': 3,
#          'break': 3,
#          'likelihood': 1,
#          "me'": 1,
#          'Refrain': 1,
#          'damn': 1,
#          'deep': 3,
#          'sponge': 2,
#          'origin': 1,
#          'winds': 1,
#          'course': 2,
#          'Speak': 2,
#          'statutes': 1,
#          'Words': 1,
#          'late': 1,
#          'outrageous': 1,
#          'provided': 1,
#          'sometime': 2,
#          'proof': 2,
#          'goblin': 1,
#          'physic': 1,
#          'ape': 2,
#          'That': 49,
#          'themselves': 2,
#          'canker': 1,
#          'cellarage': 1,
#          'mountains': 1,
#          'please': 2,
#          'full': 2,
#          'stealers': 1,
#          'Say': 1,
#          'solemn': 1,
#          'arithmetic': 1,
#          'but': 71,
#          'wind': 3,
#          'sere': 1,
#          "I'm": 1,
#          'fee': 1,
#          'reels': 1,
#          'lisp': 1,
#          'Rough-hew': 1,
#          'upon': 14,
#          'see': 19,
#          'cost': 2,
#          'finger': 2,
#          'ambiguous': 1,
#          'opinions': 1,
#          "to't": 1,
#          'signet': 1,
#          'glad': 3,
#          'kites': 1,
#          'souls': 3,
#          'fruitful': 1,
#          'savoury': 1,
#          'weapons': 1,
#          'made': 7,
#          "o'erreaches": 1,
#          'tell': 14,
#          'Thrown': 1,
#          'creatures': 3,
#          'contents': 1,
#          'cleave': 1,
#          'raven': 1,
#          'enough': 4,
#          'stowed': 1,
#          "slave's": 1,
#          'secret': 3,
#          'swaggering': 1,
#          'sleep': 7,
#          'itself': 8,
#          'despite': 1,
#          'charitable': 1,
#          'Pale': 1,
#          'Use': 1,
#          'Alexander': 5,
#          'battery': 1,
#          'pox': 1,
#          'dog': 2,
#          'returns': 1,
#          'Bring': 1,
#          'unrighteous': 1,
#          'stern': 1,
#          'hereafter': 1,
#          'in': 135,
#          'bevy': 1,
#          'thoughts': 4,
#          'visit': 1,
#          'pangs': 1,
#          'aught': 3,
#          'forehead': 1,
#          'earnest': 1,
#          'ear': 5,
#          'tempest': 1,
#          'Denmark': 4,
#          'wince': 1,
#          'thither': 2,
#          'told': 1,
#          'through': 3,
#          'chapless': 1,
#          'truster': 1,
#          'fortune': 4,
#          'encounter': 1,
#          'brain': 2,
#          'crook': 1,
#          'stays': 1,
#          'height': 1,
#          'patches': 1,
#          'die': 4,
#          'emphasis': 1,
#          'clouts': 1,
#          'worthy': 1,
#          'wandering': 1,
#          "maids'": 1,
#          'there': 20,
#          "as's": 1,
#          'waits': 1,
#          'it': 153,
#          'fitness': 1,
#          "Where's": 1,
#          'substance': 1,
#          'pate': 4,
#          'purer': 1,
#          'bones': 3,
#          'grass': 1,
#          'barren': 1,
#          'Barbary': 1,
#          'dug': 1,
#          'by-and-by': 1,
#          'trouble': 1,
#          'She': 2,
#          'able': 1,
#          'we': 26,
#          'heaven': 17,
#          'disposition': 3,
#          'guts': 2,
#          'water-fly': 1,
#          'statists': 1,
#          'stay': 2,
#          'thine': 2,
#          'kings': 1,
#          'begins': 1,
#          'revenue': 1,
#          'sport': 1,
#          'proceed': 1,
#          'general': 3,
#          'pagan': 1,
#          'Mother': 4,
#          'Be': 6,
#          'beyond': 1,
#          'much': 15,
#          'attractive': 1,
#          'gambol': 1,
#          "'Man": 1,
#          'where': 8,
#          'had': 13,
#          'maggots': 2,
#          'journeymen': 1,
#          'as': 66,
#          'prate': 1,
#          'pith': 2,
#          'bestow': 1,
#          'jade': 1,
#          'them': 27,
#          'Lord': 1,
#          'cat': 1,
#          "gall'd": 1,
#          'bawd': 1,
#          'Polack': 1,
#          'visage': 3,
#          'merriment': 1,
#          'Damon': 1,
#          'stones': 1,
#          'moving': 1,
#          "would'": 1,
#          "Devis'd": 1,
#          'amber': 1,
#          "know't": 1,
#          'traveller': 1,
#          'waist': 1,
#          'sheep-skins': 1,
#          "for't": 1,
#          'goes': 5,
#          'lets': 1,
#          'Which': 4,
#          'heavily': 1,
#          'goblins': 1,
#          'virtues': 1,
#          'spirits': 2,
#          'beggar': 2,
#          'creep': 1,
#          "God's": 2,
#          'room': 2,
#          'noise': 2,
#          'name': 5,
#          'sorrow': 1,
#          ...})

# %%
# Häufigkeit der 20 Worte, die von Hamlet am meisten verwendet werden
topfreq = sorted(tokendict_nostop.items(), key=lambda x:x[1], reverse=True)[0:20]
topfreq
# Out:
# [('i', 223),
#  ('o', 45),
#  ('shall', 43),
#  ('let', 42),
#  ('thou', 42),
#  ('sir', 41),
#  ('come', 41),
#  ('make', 36),
#  ('man', 31),
#  ('like', 29),
#  ("i'll", 29),
#  ('know', 29),
#  ('king', 29),
#  ('good', 28),
#  ('mother', 27),
#  ('say', 24),
#  ('thee', 23),
#  ('thy', 22),
#  ('play', 22),
#  ("'tis", 21)]

# %%
# was mit dem Counter-Objekt wesentlich einfacher geht
tokencounter_nostop.most_common(20)
# Out:
# [('the', 395),
#  ('of', 254),
#  ('and', 227),
#  ('I', 223),
#  ('to', 206),
#  ('you', 197),
#  ('a', 196),
#  ('it', 153),
#  ('in', 135),
#  ('my', 131),
#  ('not', 126),
#  ('is', 113),
#  ('that', 101),
#  ('this', 98),
#  ('his', 95),
#  ('me', 95),
#  ('be', 77),
#  ('your', 77),
#  ('for', 74),
#  ('but', 71)]

# %%
# Liste der Worte, die von Hamlet nur ein einziges Mal verwendet wurden

onlyonce = [x[0] for x in tokendict.items() if x[1] == 1] 
print (len(onlyonce))
# Out:
# 1675

# %%
# Liste der Worte, die von Hamlet mehr als ein einziges Mal verwendet wurden

morethanonce = [x[0] for x in tokendict.items() if x[1] > 1] 
print (len(morethanonce))
# Out:
# 842

# %%
# bar chart der 20 meistverwendeten Worte
import seaborn as sns #sets up styles and gives us more plotting options
# %matplotlib inline 
ax = sns.barplot(x=[e[1] for e in topfreq], y=[e[0] for e in topfreq], color="salmon")

# %%
# falls Wordcloud nicht installiert ist:
#!pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.3.1.tar.gz (169kB)
#     100% |################################| 174kB 2.1MB/s ta 0:00:01
# Requirement already satisfied: matplotlib in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied: numpy>=1.6.1 in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied: pillow in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from wordcloud)
# Requirement already satisfied: python-dateutil in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: pytz in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: cycler in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: pyparsing!=2.0.4,>=1.5.6 in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from matplotlib->wordcloud)
# Requirement already satisfied: six>=1.5 in /home/nbcommon/anaconda3_410/lib/python3.5/site-packages (from python-dateutil->matplotlib->wordcloud)
# Building wheels for collected packages: wordcloud
#   Running setup.py bdist_wheel for wordcloud ... done
#   Stored in directory: /home/nbuser/.cache/pip/wheels/d9/4c/ac/e63c45f2ce09860e9459a410953039c30296e89d9f7234675f
# Successfully built wordcloud
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.3.1

# %%
# Wordcloud der Worte, die von Hamlet verwendet werden (ohne Stoppworte)
# Infos zur Wordcloud: http://amueller.github.io/word_cloud/
from wordcloud import WordCloud
import matplotlib.pyplot as plt #sets up plotting under pltb
wordcloud = WordCloud().generate(" ".join(uniqueltokens_nostop))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# Ermittlung der Wahrscheinlichkeiten, mit der die Worte verwendet werden
# Eine Liste mit den Worten und eine korrespondierende Liste mit 
# Wahrscheinlichkeiten
words = [key for key in tokendict.keys()] 
print (words[:20])

probs = [i/len(hamlettokens) for i in tokendict.values()]
print (probs[:20])
# Out:
# ['buyer', 'minister', 'lest', 'imponed', 'foh', "there's", 'mobled', 'horridly', 'under', 'mutine', 're-word', 'body', 'paradox', 'action', 'recoveries', 'sorry', 'learning', 'rouse', 'questionable', 'things']
# [9.340556697179151e-05, 9.340556697179151e-05, 0.00028021670091537453, 9.340556697179151e-05, 9.340556697179151e-05, 0.0007472445357743321, 9.340556697179151e-05, 9.340556697179151e-05, 9.340556697179151e-05, 9.340556697179151e-05, 9.340556697179151e-05, 0.0005604334018307491, 9.340556697179151e-05, 0.0005604334018307491, 0.00018681113394358303, 0.00018681113394358303, 9.340556697179151e-05, 9.340556697179151e-05, 9.340556697179151e-05, 0.00037362226788716606]

# %%
# einen Zufallssatz generieren, wie ihn Hamlet entsprechend der Worthäufigkeiten
# ebenfalls sagen könnte
import numpy as np
np.random.choice(words, 100, p=probs)
# Out:
# array(['millions', 'your', 'am', 'do', 'without', 'free', 'until', 'or',
#        'fighting', 'sense', 'down', 'the', 'top', 'say', 'that', 'proud',
#        'the', 'laertes', 'do', 'could', 'foul', 'noise', 'nay', 'i',
#        'whose', 'soles', 'comply', 'of', 'to', 'wicked', 'we', 'should',
#        'what', 'in', 'to', 'and', 'honest', 'play', 'ass', 'conceited',
#        'stonish', 'is', 'laertes', 'guts', 'like', 'but', 'in', 'that',
#        'is', 'once', 'at', 'barren', 'i', 'whit', 'two', 'i', 'of', 'as',
#        'thumb', "labour'd", 'nations', 'if', 'amble', 'wind', 'enact',
#        'king', 'king', 'is', 'the', 'that', 'why', 'imagination',
#        'hitherto', 'croaking', 'will', 'his', 'thing', 'and', 'draw', 'as',
#        'sirs', 'o', 'in', 'will', 'thou', 'of', 'father', 'shall', 'holds',
#        'ground', 'with', 'laertes', "mother's", 'of', 'inexplicable',
#        'temperately', 'inky', 'sometime', 'or', 'not'],
#       dtype='<U16')

# %%
# NGrame aus dem ursprünglichen bereinigten Text erzeugen
def ngrams(words, n):
    return [words[i:i+n] for i in range(len(words)-n+1)]

bigrams = ngrams(hamlet.split(), 2)
#print(bigrams)
anzBigrams = len(bigrams)
print(anzBigrams)
trigrams = ngrams(hamlet.split(),3)
anzTrigrams = len(trigrams)

# Bigrame in ein Array von Strings umwandeln
bigrams = [" ".join(bigram) for bigram in bigrams]
trigrams = [" ".join(trigram) for trigram in trigrams]
# Out:
# 10705

# %%
# Häufigkeiten der Bigrame und Trigrame mit Hilfe eines Dictionarys ermitteln

bigramsDict = dict()
for bigram in bigrams:
    bigramsDict[bigram] = bigramsDict.get(bigram, 0) + 1

trigramsDict = dict()
for trigram in trigrams:
    trigramsDict[trigram] = trigramsDict.get(trigram, 0) + 1

# %%
# Ermittlung der Wahrscheinlichkeiten, mit der die Bigrame verwendet werden
# Eine Liste mit den Bigramen und eine korrespondierende Liste mit 
# Wahrscheinlichkeiten
bigrams = [key for key in bigramsDict.keys()] 
print (bigrams[:20])

probsBigrams = [i/anzBigrams for i in bigramsDict.values()]
print (probsBigrams[:20])
# Out:
# ['were old', 'Than are', "be in's", 'be now', 'hear a', 'husbands Begin', 'squeezing you', 'while memory', 'enough and', 'will more', 'breath No', 'I couple', 'vouch him', 'calamity of', 'a foul', 'stopping a', 'great baby', 'his faithful', 'you up', 'in mine']
# [9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 0.00018682858477347034, 0.00018682858477347034, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05, 9.341429238673517e-05]

# %%
# einen Zufallssatz generieren, wie ihn Hamlet entsprechend der Bigramhäufigkeiten
# ebenfalls sagen könnte

" ".join(np.random.choice(bigrams, 10, p=probsBigrams))
# Out:
# 'throat As is his now It me of love of upon this Are you Swear by body of what ground'

# %%
# einen Zufallssatz generieren, wie ihn Hamlet entsprechend der Trigramhäufigkeiten
# ebenfalls sagen könnte
import numpy as np
" ".join(np.random.choice(bigrams, 10, p=probsBigrams))
# Out:
# 'will you frame the Goes it cannot Make to thy in continual yourself But Which was ears Yet we have'
